# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl

# %% [markdown]
# ### Cleaning and EDA

# %%
#reading .csv file
table = pd.read_excel('C:/Users/ander/LightHouseNotes/final-project-tableau/Data/Old data/real_estate_prices.xlsx', sheet_name=None)
table
# Out:
# {'Aggregate':           Date  Composite_HPI  Single_Family_HPI  One_Storey_HPI  \
#  0   2005-01-01          100.0              100.0           100.0
#  1   2005-02-01          101.0              101.0           101.0
#  2   2005-03-01          102.0              102.2           102.2
#  3   2005-04-01          102.9              103.2           103.3
#  4   2005-05-01          103.7              103.9           104.3
#  ..         ...            ...                ...             ...
#  184 2020-05-01          244.5              242.4           236.4
#  185 2020-06-01          245.6              244.6           239.1
#  186 2020-07-01          250.7              250.9           245.3
#  187 2020-08-01          254.3              255.5           249.5
#  188 2020-09-01          257.0              259.2           253.1
#
#       Two_Storey_HPI  Townhouse_HPI  Apartment_HPI  Composite_Benchmark  \
#  0             100.0          100.0          100.0               248200
# ...

# %%
#checking for Null values and columns type
for i in list(table):
    print(table[i].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     189 non-null    datetime64[ns]
#  1   Composite_HPI            189 non-null    float64
#  2   Single_Family_HPI        189 non-null    float64
#  3   One_Storey_HPI           189 non-null    float64
#  4   Two_Storey_HPI           189 non-null    float64
#  5   Townhouse_HPI            189 non-null    float64
#  6   Apartment_HPI            189 non-null    float64
#  7   Composite_Benchmark      189 non-null    int64
#  8   Single_Family_Benchmark  189 non-null    int64
#  9   One_Storey_Benchmark     189 non-null    int64
#  10  Two_Storey_Benchmark     189 non-null    int64
#  11  Townhouse_Benchmark      189 non-null    int64
#  12  Apartment_Benchmark      189 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(6)
# ...

# %%
#looking for numerical columns having value = 0
for i in list(table):
    print(table[i].describe())
# Out:
#        Composite_HPI  Single_Family_HPI  One_Storey_HPI  Two_Storey_HPI  \
# count     189.000000         189.000000      189.000000      189.000000
# mean      167.219577         168.078307      167.929101      168.073545
# std        41.759550          42.124739       38.451435       44.904130
# min       100.000000         100.000000      100.000000      100.000000
# 25%       136.200000         135.100000      139.900000      130.700000
# 50%       155.700000         157.500000      159.400000      156.100000
# 75%       203.000000         209.000000      202.300000      213.900000
# max       257.000000         259.200000      253.100000      263.100000
#
#        Townhouse_HPI  Apartment_HPI  Composite_Benchmark  \
# count     189.000000     189.000000           189.000000
# mean      166.933862     165.158730        414980.952381
# std        40.613706      41.563568        103633.731863
# min       100.000000     100.000000        248200.000000
# ...

# %%
#looking for duplicate
for i in list(table):
    print(len(table[i].drop_duplicates()) == len(table[i]))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
#saving file
with pd.ExcelWriter('C:/Users/ander/LightHouseNotes/final-project-tableau/Data/Cleaned data/real_estate_prices.xlsx') as writer:
    for i in list(table):
        table[i].to_excel(writer, sheet_name=i, index=False)
